# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('BukuPinjam.csv')
df
# Out:
#      kategori_buku               nama_anggota  kode_buku  pinjam
# 0    Kesusasteraan       A.MEYSHERLY FERAYU W        800       1
# 1    Kesusasteraan             AFIFAHZULAIKHA        800       1
# 2    Kesusasteraan         AFLA AZZAHRA PUTRI        800       1
# 3    Kesusasteraan     AGRISHAM RIFKY ALVALEN        800       1
# 4      Agama Islam  AGUNG SULISTIYANA HIDAYAT        297       1
# ..             ...                        ...        ...     ...
# 731  Kesusasteraan                AHMAD DAHRI        800      18
# 732  Kesusasteraan          CATUR NURHIDAYATI        800      18
# 733  Kesusasteraan    FIRDA OCTAVIA INDRADEWI        800      18
# 734  Kesusasteraan           WAYA KURNIA WATI        800      18
# 735  Kesusasteraan             BRIGITA JEANNY        800      22
#
# [736 rows x 4 columns]

# %%
#menghaous kolom
df.drop(df.columns[[0, 1]], axis = 1, inplace = True)
df
# Out:
#      kode_buku  pinjam
# 0          800       1
# 1          800       1
# 2          800       1
# 3          800       1
# 4          297       1
# ..         ...     ...
# 731        800      18
# 732        800      18
# 733        800      18
# 734        800      18
# 735        800      22
#
# [736 rows x 2 columns]

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['pinjam']])
# y_predicted

# %%
df['cluster'] = y_predicted
df
# Out:
#      kode_buku  pinjam  cluster
# 0          800       1        2
# 1          800       1        2
# 2          800       1        2
# 3          800       1        2
# 4          297       1        2
# ..         ...     ...      ...
# 731        800      18        1
# 732        800      18        1
# 733        800      18        1
# 734        800      18        1
# 735        800      22        1
#
# [736 rows x 3 columns]

# %%
km.cluster_centers_
# Out:
# array([[ 5.43884892],
#        [13.53125   ],
#        [ 1.54690265]])

# %%
sns.lmplot('kode_buku', 'pinjam', data=df, hue='cluster', fit_reg=False)
